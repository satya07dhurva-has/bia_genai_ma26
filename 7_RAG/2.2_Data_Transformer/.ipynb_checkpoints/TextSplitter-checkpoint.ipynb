# %% [markdown]
# #### Text Splitting from Documents- RecursiveCharacter Text Splitters
# This text splitter is the recommended one for generic text. It is parameterized by a list of characters. It tries to split on them in order until the chunks are small enough. The default list is ["\n\n", "\n", " ", ""]. This has the effect of trying to keep all paragraphs (and then sentences, and then words) together as long as possible, as those would generically seem to be the strongest semantically related pieces of text.
#
# - How the text is split: by list of characters.
# - How the chunk size is measured: by number of characters.

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("rag_sample_document.pdf")
docs = loader.load()


docs
# Out:
# [Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='An Introduction to Retrieval-Augmented Generation\n(RAG)\nDocument ID: TECH-RAG-2026-001 | Classification: Public\nRetrieval-Augmented Generation (RAG) is an advanced architectural framework designed to optimize the\noutput of Large Language Models (LLMs) by sourcing authoritative data from external knowledge bases\nbefore generating a response. Traditional language models rely solely on internal parametric knowledge\nacquired  during  their  initial  training  phases,  which  often  renders  them  susceptible  to  factual\nhallucinations and outdated references. By decoupling the static intelligence of the model from dynamic,\ndomain-specific information repositories, RAG systems ensure that the synthesized insights are both\ncontextually accurate and verifiably grounded in real-time enterprise data. \nThe underlying workflow of a standard RAG pipeline initiates when a user submits a textual query, which\nis immediately converted into a dense vector embedding using a specialized text-embedding model. This\nnumerical representation is then cross-referenced against a high-dimensional vector database containing\npre-chunked and indexed proprietary documents, allowing the system to perform an efficient semantic\nsimilarity search. The top-ranking document segments that match the intent of the query are retrieved\nand dynamically injected into the system prompt, serving as an enriched context layer that guides the\nsubsequent generative process. \nImplementing RAG provides substantial operational advantages to enterprise engineering teams, most\nnotably  by  drastically  mitigating  the  steep  computational  expenses  associated  with  fine-tuning  or\nretraining foundation models. Furthermore, it introduces a robust layer of auditable transparency, as\ngenerated text can be directly mapped back to specific source citations within the connected vector\nstorage infrastructure. This level of traceability allows organizations to implement fine-grained role-based\naccess controls over sensitive corporate data, ensuring the model only references source material that\nthe inquiring user is explicitly authorized to view.')]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
final_documents = text_splitter.split_documents(docs)

final_documents
# Out:
# [Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='An Introduction to Retrieval-Augmented Generation\n(RAG)\nDocument ID: TECH-RAG-2026-001 | Classification: Public\nRetrieval-Augmented Generation (RAG) is an advanced architectural framework designed to optimize the\noutput of Large Language Models (LLMs) by sourcing authoritative data from external knowledge bases\nbefore generating a response. Traditional language models rely solely on internal parametric knowledge\nacquired  during  their  initial  training  phases,  which  often  renders  them  susceptible  to  factual\nhallucinations and outdated references. By decoupling the static intelligence of the model from dynamic,\ndomain-specific information repositories, RAG systems ensure that the synthesized insights are both\ncontextually accurate and verifiably grounded in real-time enterprise data. \nThe underlying workflow of a standard RAG pipeline initiates when a user submits a textual query, which'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='contextually accurate and verifiably grounded in real-time enterprise data. \nThe underlying workflow of a standard RAG pipeline initiates when a user submits a textual query, which\nis immediately converted into a dense vector embedding using a specialized text-embedding model. This\nnumerical representation is then cross-referenced against a high-dimensional vector database containing\npre-chunked and indexed proprietary documents, allowing the system to perform an efficient semantic\nsimilarity search. The top-ranking document segments that match the intent of the query are retrieved\nand dynamically injected into the system prompt, serving as an enriched context layer that guides the\nsubsequent generative process. \nImplementing RAG provides substantial operational advantages to enterprise engineering teams, most\nnotably  by  drastically  mitigating  the  steep  computational  expenses  associated  with  fine-tuning  or'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='notably  by  drastically  mitigating  the  steep  computational  expenses  associated  with  fine-tuning  or\nretraining foundation models. Furthermore, it introduces a robust layer of auditable transparency, as\ngenerated text can be directly mapped back to specific source citations within the connected vector\nstorage infrastructure. This level of traceability allows organizations to implement fine-grained role-based\naccess controls over sensitive corporate data, ensuring the model only references source material that\nthe inquiring user is explicitly authorized to view.')]

# %%
len(final_documents)
# Out:
# 3

# %%
final_documents[0].page_content
# Out:
# 'An Introduction to Retrieval-Augmented Generation\n(RAG)\nDocument ID: TECH-RAG-2026-001 | Classification: Public\nRetrieval-Augmented Generation (RAG) is an advanced architectural framework designed to optimize the\noutput of Large Language Models (LLMs) by sourcing authoritative data from external knowledge bases\nbefore generating a response. Traditional language models rely solely on internal parametric knowledge\nacquired  during  their  initial  training  phases,  which  often  renders  them  susceptible  to  factual\nhallucinations and outdated references. By decoupling the static intelligence of the model from dynamic,\ndomain-specific information repositories, RAG systems ensure that the synthesized insights are both\ncontextually accurate and verifiably grounded in real-time enterprise data. \nThe underlying workflow of a standard RAG pipeline initiates when a user submits a textual query, which'

# %%
final_documents[1].page_content
# Out:
# 'contextually accurate and verifiably grounded in real-time enterprise data. \nThe underlying workflow of a standard RAG pipeline initiates when a user submits a textual query, which\nis immediately converted into a dense vector embedding using a specialized text-embedding model. This\nnumerical representation is then cross-referenced against a high-dimensional vector database containing\npre-chunked and indexed proprietary documents, allowing the system to perform an efficient semantic\nsimilarity search. The top-ranking document segments that match the intent of the query are retrieved\nand dynamically injected into the system prompt, serving as an enriched context layer that guides the\nsubsequent generative process. \nImplementing RAG provides substantial operational advantages to enterprise engineering teams, most\nnotably  by  drastically  mitigating  the  steep  computational  expenses  associated  with  fine-tuning  or'

# %%
from langchain_text_splitters import CharacterTextSplitter

text_splitter = CharacterTextSplitter(separator=  "\n",chunk_size=25, chunk_overlap=20)

text_splitter.split_documents(docs)
# Out:
# Created a chunk of size 49, which is longer than the specified 25
# Created a chunk of size 55, which is longer than the specified 25
# Created a chunk of size 100, which is longer than the specified 25
# Created a chunk of size 99, which is longer than the specified 25
# Created a chunk of size 102, which is longer than the specified 25
# Created a chunk of size 106, which is longer than the specified 25
# Created a chunk of size 104, which is longer than the specified 25
# Created a chunk of size 99, which is longer than the specified 25
# Created a chunk of size 76, which is longer than the specified 25
# Created a chunk of size 103, which is longer than the specified 25
# Created a chunk of size 101, which is longer than the specified 25
# Created a chunk of size 103, which is longer than the specified 25
# Created a chunk of size 99, which is longer than the specified 25
# Created a chunk of size 101, which is longer than the specified 25
# Created a chunk of size 101, which is longer than the specified 25
# Created a chunk of size 31, which is longer than the specified 25
# Created a chunk of size 98, which is longer than the specified 25
# Created a chunk of size 108, which is longer than the specified 25
# Created a chunk of size 101, which is longer than the specified 25
# Created a chunk of size 99, which is longer than the specified 25
# Created a chunk of size 108, which is longer than the specified 25
# Created a chunk of size 102, which is longer than the specified 25
# [Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='An Introduction to Retrieval-Augmented Generation'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='(RAG)'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Document ID: TECH-RAG-2026-001 | Classification: Public'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Retrieval-Augmented Generation (RAG) is an advanced architectural framework designed to optimize the'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='output of Large Language Models (LLMs) by sourcing authoritative data from external knowledge bases'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='before generating a response. Traditional language models rely solely on internal parametric knowledge'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='acquired  during  their  initial  training  phases,  which  often  renders  them  susceptible  to  factual'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='hallucinations and outdated references. By decoupling the static intelligence of the model from dynamic,'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='domain-specific information repositories, RAG systems ensure that the synthesized insights are both'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='contextually accurate and verifiably grounded in real-time enterprise data.'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='The underlying workflow of a standard RAG pipeline initiates when a user submits a textual query, which'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='is immediately converted into a dense vector embedding using a specialized text-embedding model. This'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='numerical representation is then cross-referenced against a high-dimensional vector database containing'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='pre-chunked and indexed proprietary documents, allowing the system to perform an efficient semantic'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='similarity search. The top-ranking document segments that match the intent of the query are retrieved'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='and dynamically injected into the system prompt, serving as an enriched context layer that guides the'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='subsequent generative process.'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Implementing RAG provides substantial operational advantages to enterprise engineering teams, most'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='notably  by  drastically  mitigating  the  steep  computational  expenses  associated  with  fine-tuning  or'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='retraining foundation models. Furthermore, it introduces a robust layer of auditable transparency, as'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='generated text can be directly mapped back to specific source citations within the connected vector'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='storage infrastructure. This level of traceability allows organizations to implement fine-grained role-based'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='access controls over sensitive corporate data, ensuring the model only references source material that'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Sample RAG Document', 'source': 'rag_sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='the inquiring user is explicitly authorized to view.')]

# %%
len(text_splitter.split_documents(docs))
# Out:
# 1

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter
