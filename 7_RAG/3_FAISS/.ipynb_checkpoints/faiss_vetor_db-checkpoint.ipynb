# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os
os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
embeddings = HuggingFaceEmbeddings(model_name = "all-MiniLM-L6-v2")

# %%
embed = embeddings.embed_query("Hello AI")

# %%
len(embed)
# Out:
# 384

# %%
embed = embeddings.embed_query("Hello AI, this is genai concepts")

# %%
len(embed)
# Out:
# 384

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
documents = [
             "What is the capital of USA?",
             "Who is the president of USA?",
             "WHo is prime minister of India?"
            ]

# %%
my_query = "Narendra Modi is the prime minister of India"

# %%
document_embeddings = embeddings.embed_documents(documents)

# %%
len(document_embeddings)
# Out:
# 3

# %%
len(document_embeddings[0]) # ---> first stateent
# Out:
# 384

# %%
len(document_embeddings[1])
# Out:
# 384

# %%
len(document_embeddings[2])
# Out:
# 384

# %%
query_embeddings = embeddings.embed_query(my_query)

# %%
len(query_embeddings)
# Out:
# 384

# %%
cosine_similarity([query_embeddings],document_embeddings)
# Out:
# array([[0.06192698, 0.31278137, 0.73973244]])

# %%
my_query = "Leader of the countries"
query_embeddings = embeddings.embed_query(my_query)
cosine_similarity([query_embeddings],document_embeddings)
# Out:
# array([[0.27063273, 0.5998015 , 0.57583515]])

# %%
from sklearn.metrics.pairwise import euclidean_distances

# %%
euclidean_distances([query_embeddings], document_embeddings)
# Out:
# array([[1.20778083, 0.8946491 , 0.92104816]])

# %% [markdown]
# | Metric            | Similarity Score Range | Behavior                              |
# | ----------------- | ---------------------- | ------------------------------------- |
# | Cosine Similarity | \[-1, 1]               | Focuses on angle only |
# | L2 Distance       | \[0, ∞)                | Focuses on **magnitude + direction**  |

# %%
import faiss
import chromadb
from langchain_community.vectorstores import FAISS, Chroma
from langchain_community.docstore.in_memory import InMemoryDocstore
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3576\2203642273.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import FAISS, Chroma

# %%
# Index first


index = faiss.IndexFlatL2(384)

# %%
index
# Out:
# <faiss.swigfaiss_avx2.IndexFlatL2; proxy of <Swig Object of type 'faiss::IndexFlatL2 *' at 0x0000013F1C323CC0> >

# %%
vector_store = FAISS(
    embedding_function=embeddings,
    index=index,
    docstore=InMemoryDocstore(),
    index_to_docstore_id = {},
)

# %%
vector_store

# %%
vector_store.add_texts(["AI is future", "AI is powerful", "Dogs are cute", "Pizza is good", "I like mexican food"])
# Out:
# ['29d3e9ac-1cac-482f-ba92-9d50f2a42582',
#  'f679fd84-7631-4dd2-bb55-5b49022938f9',
#  '0eb60080-9230-44d5-b617-d9beefe92e06',
#  '07c44894-afba-47e7-8fce-27fe6ed3e2df',
#  'e1c6fa35-6a89-44a4-b81a-fdfe7f2a79fc']

# %%
vector_store.index_to_docstore_id
# Out:
# {0: '29d3e9ac-1cac-482f-ba92-9d50f2a42582',
#  1: 'f679fd84-7631-4dd2-bb55-5b49022938f9',
#  2: '0eb60080-9230-44d5-b617-d9beefe92e06',
#  3: '07c44894-afba-47e7-8fce-27fe6ed3e2df',
#  4: 'e1c6fa35-6a89-44a4-b81a-fdfe7f2a79fc'}

# %%
faiss_index = 1
docstore_id = vector_store.index_to_docstore_id[faiss_index]
print(docstore_id)
# Out:
# f679fd84-7631-4dd2-bb55-5b49022938f9

# %%
vector_store.docstore.search(docstore_id)
# Out:
# Document(id='f679fd84-7631-4dd2-bb55-5b49022938f9', metadata={}, page_content='AI is powerful')

# %%
results = vector_store.similarity_search("Tell me about AI",k=2)

# Tell me about AI ---> embeddings (embedding model)
# Configurations in Index --> similarity
# Ordr them and filter them and give us k documents

# %%
results
# Out:
# [Document(id='f679fd84-7631-4dd2-bb55-5b49022938f9', metadata={}, page_content='AI is powerful'),
#  Document(id='29d3e9ac-1cac-482f-ba92-9d50f2a42582', metadata={}, page_content='AI is future')]

# %%
results = vector_store.similarity_search("I love cat",k=2)

# %%
results
# Out:
# [Document(id='0eb60080-9230-44d5-b617-d9beefe92e06', metadata={}, page_content='Dogs are cute'),
#  Document(id='e1c6fa35-6a89-44a4-b81a-fdfe7f2a79fc', metadata={}, page_content='I like mexican food')]

# %%
results = vector_store.similarity_search("I love cat",k=5)

# %%
results
# Out:
# [Document(id='0eb60080-9230-44d5-b617-d9beefe92e06', metadata={}, page_content='Dogs are cute'),
#  Document(id='e1c6fa35-6a89-44a4-b81a-fdfe7f2a79fc', metadata={}, page_content='I like mexican food'),
#  Document(id='07c44894-afba-47e7-8fce-27fe6ed3e2df', metadata={}, page_content='Pizza is good'),
#  Document(id='f679fd84-7631-4dd2-bb55-5b49022938f9', metadata={}, page_content='AI is powerful'),
#  Document(id='29d3e9ac-1cac-482f-ba92-9d50f2a42582', metadata={}, page_content='AI is future')]

# %%
results = vector_store.similarity_search("My favourite super hero",k=5)
results
# Out:
# [Document(id='f679fd84-7631-4dd2-bb55-5b49022938f9', metadata={}, page_content='AI is powerful'),
#  Document(id='0eb60080-9230-44d5-b617-d9beefe92e06', metadata={}, page_content='Dogs are cute'),
#  Document(id='29d3e9ac-1cac-482f-ba92-9d50f2a42582', metadata={}, page_content='AI is future'),
#  Document(id='e1c6fa35-6a89-44a4-b81a-fdfe7f2a79fc', metadata={}, page_content='I like mexican food'),
#  Document(id='07c44894-afba-47e7-8fce-27fe6ed3e2df', metadata={}, page_content='Pizza is good')]

# %% [markdown]
# | Feature               | `Flat`                | `IVF` (Inverted File Index)        | `HNSW` (Graph-based Index)          |
# | --------------------- | --------------------- | ---------------------------------- | ----------------------------------- |
# | Type of Search     | Exact                 | Approximate (cluster-based)        | Approximate (graph-based traversal) |
# | Speed               | Slow (linear scan)    | Fast (search only in top clusters) | Very Fast (graph walk)              |

# %% [markdown]
# | Dataset Size              | Recommended Index                 |
# | ------------------------- | --------------------------------- |
# | UPTO 1L                     | `IndexFlatL2` or `IndexFlatIP`    |
# | UPTO 1M                  | `IndexIVFFlat` or `IndexHNSWFlat` |
# | > 1M                      | `IndexIVFPQ` or `IndexHNSWFlat`   |

# %%
# from uuid import uuid4
from langchain_core.documents import Document

document_1 = Document(
    page_content="I had chocolate chip pancakes and scrambled eggs for breakfast this morning.",
    metadata={"source": "tweet"},
)

document_2 = Document(
    page_content="The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.",
    metadata={"source": "news"},
)

document_3 = Document(
    page_content="Building an exciting new project with LangChain - come check it out!",
    metadata={"source": "tweet"},
)

document_4 = Document(
    page_content="Robbers broke into the city bank and stole $1 million in cash.",
    metadata={"source": "news"},
)

document_5 = Document(
    page_content="Wow! That was an amazing movie. I can't wait to see it again.",
    metadata={"source": "tweet"},
)

document_6 = Document(
    page_content="Is the new iPhone worth the price? Read this review to find out.",
    metadata={"source": "website"},
)

document_7 = Document(
    page_content="The top 10 soccer players in the world right now.",
    metadata={"source": "website"},
)

document_8 = Document(
    page_content="LangGraph is the best framework for building stateful, agentic applications!",
    metadata={"source": "tweet"},
)

document_9 = Document(
    page_content="The stock market is down 500 points today due to fears of a recession.",
    metadata={"source": "news"},
)

document_10 = Document(
    page_content="I have a bad feeling I am going to get deleted :(",
    metadata={"source": "tweet"},
)

documents = [
    document_1,
    document_2,
    document_3,
    document_4,
    document_5,
    document_6,
    document_7,
    document_8,
    document_9,
    document_10,
]

# %%
documents
# Out:
# [Document(metadata={'source': 'tweet'}, page_content='I had chocolate chip pancakes and scrambled eggs for breakfast this morning.'),
#  Document(metadata={'source': 'news'}, page_content='The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.'),
#  Document(metadata={'source': 'tweet'}, page_content='Building an exciting new project with LangChain - come check it out!'),
#  Document(metadata={'source': 'news'}, page_content='Robbers broke into the city bank and stole $1 million in cash.'),
#  Document(metadata={'source': 'tweet'}, page_content="Wow! That was an amazing movie. I can't wait to see it again."),
#  Document(metadata={'source': 'website'}, page_content='Is the new iPhone worth the price? Read this review to find out.'),
#  Document(metadata={'source': 'website'}, page_content='The top 10 soccer players in the world right now.'),
#  Document(metadata={'source': 'tweet'}, page_content='LangGraph is the best framework for building stateful, agentic applications!'),
#  Document(metadata={'source': 'news'}, page_content='The stock market is down 500 points today due to fears of a recession.'),
#  Document(metadata={'source': 'tweet'}, page_content='I have a bad feeling I am going to get deleted :(')]

# %%
index = faiss.IndexFlatIP(384)
vector_store = FAISS(
    embedding_function=embeddings,
    index= index,
    docstore=InMemoryDocstore(),
    index_to_docstore_id={},
)

# %%
vector_store.add_documents(documents = documents)
# Out:
# ['1b7728c1-33b9-4604-bc01-31bdce06c46d',
#  '800098cd-3693-4e88-8327-747060b37b19',
#  '354834fc-5e2c-4a45-bf3d-318b55268d1c',
#  '42003747-83dd-45a9-9889-fa8edf0c5115',
#  '70ce78a2-dba8-44d2-8d4c-a648dfc27973',
#  '6b04ad76-1f1f-42a2-8d05-d51c08286808',
#  'c5456ded-bdd7-47af-a439-83dd53308332',
#  'f7975f28-9cc6-4508-9bdb-c2c88f903230',
#  '6aa0d251-de86-44cb-b2b6-104bb33fae09',
#  'c59a514b-53f5-4b5b-9cc7-a3cbfeb278fd']

# %%
vector_store.add_texts(["AI is future", "AI is powerful", "Dogs are cute", "Pizza is good", "I like mexican food"])
# Out:
# ['7a36738b-c853-4c1c-ab2f-5bd61f78645c',
#  '1806aedd-3af3-416e-812c-78373dcf2071',
#  'bc0c0f6c-628a-42d2-92c4-267b8fc53fbf',
#  '716e42e6-0b36-45ca-bcbb-93d1be56866e',
#  '944f6afb-4e7e-49a4-b908-0c7f666bb98c']

# %%
vector_store.index_to_docstore_id
# Out:
# {0: '1b7728c1-33b9-4604-bc01-31bdce06c46d',
#  1: '800098cd-3693-4e88-8327-747060b37b19',
#  2: '354834fc-5e2c-4a45-bf3d-318b55268d1c',
#  3: '42003747-83dd-45a9-9889-fa8edf0c5115',
#  4: '70ce78a2-dba8-44d2-8d4c-a648dfc27973',
#  5: '6b04ad76-1f1f-42a2-8d05-d51c08286808',
#  6: 'c5456ded-bdd7-47af-a439-83dd53308332',
#  7: 'f7975f28-9cc6-4508-9bdb-c2c88f903230',
#  8: '6aa0d251-de86-44cb-b2b6-104bb33fae09',
#  9: 'c59a514b-53f5-4b5b-9cc7-a3cbfeb278fd',
#  10: '7a36738b-c853-4c1c-ab2f-5bd61f78645c',
#  11: '1806aedd-3af3-416e-812c-78373dcf2071',
#  12: 'bc0c0f6c-628a-42d2-92c4-267b8fc53fbf',
#  13: '716e42e6-0b36-45ca-bcbb-93d1be56866e',
#  14: '944f6afb-4e7e-49a4-b908-0c7f666bb98c'}

# %%
vector_store.similarity_search("Langchain provides abstractions to make working with LLMs easy",
                               k=2) #Hyperparameter
# Out:
# [Document(id='354834fc-5e2c-4a45-bf3d-318b55268d1c', metadata={'source': 'tweet'}, page_content='Building an exciting new project with LangChain - come check it out!'),
#  Document(id='f7975f28-9cc6-4508-9bdb-c2c88f903230', metadata={'source': 'tweet'}, page_content='LangGraph is the best framework for building stateful, agentic applications!')]

# %%
vector_store.similarity_search("Which animal is cute?",
                               k=2) #Hyperparameter
# Out:
# [Document(id='bc0c0f6c-628a-42d2-92c4-267b8fc53fbf', metadata={}, page_content='Dogs are cute'),
#  Document(id='944f6afb-4e7e-49a4-b908-0c7f666bb98c', metadata={}, page_content='I like mexican food')]

# %%
vector_store.similarity_search(
    "Langchain provides abstractions to make working with LLMs easy",
    k=4,
    filter = {"source" : {"$eq": "news"}}
)
# Out:
# [Document(id='42003747-83dd-45a9-9889-fa8edf0c5115', metadata={'source': 'news'}, page_content='Robbers broke into the city bank and stole $1 million in cash.'),
#  Document(id='800098cd-3693-4e88-8327-747060b37b19', metadata={'source': 'news'}, page_content='The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.'),
#  Document(id='6aa0d251-de86-44cb-b2b6-104bb33fae09', metadata={'source': 'news'}, page_content='The stock market is down 500 points today due to fears of a recession.')]

# %%
vector_store.similarity_search_with_score("Langchain provides abstractions to make working with LLMs easy",
    k=4)
# Out:
# [(Document(id='354834fc-5e2c-4a45-bf3d-318b55268d1c', metadata={'source': 'tweet'}, page_content='Building an exciting new project with LangChain - come check it out!'),
#   np.float32(0.57917786)),
#  (Document(id='f7975f28-9cc6-4508-9bdb-c2c88f903230', metadata={'source': 'tweet'}, page_content='LangGraph is the best framework for building stateful, agentic applications!'),
#   np.float32(0.49078575)),
#  (Document(id='7a36738b-c853-4c1c-ab2f-5bd61f78645c', metadata={}, page_content='AI is future'),
#   np.float32(0.16697761)),
#  (Document(id='1806aedd-3af3-416e-812c-78373dcf2071', metadata={}, page_content='AI is powerful'),
#   np.float32(0.13363138))]

# %%
retriever = vector_store.as_retriever(
    search_type="similarity_score_threshold",
    search_kwargs = {
        "score_threshold" : 0.001,
        })

# %%
vector_store.save_local("BIA FAISS Langchain")

# %%
new_vector_store = FAISS.load_local("BIA FAISS Langchain", embeddings,allow_dangerous_deserialization=True)

# %%
new_vector_store.similarity_search("Langchain")
# Out:
# [Document(id='354834fc-5e2c-4a45-bf3d-318b55268d1c', metadata={'source': 'tweet'}, page_content='Building an exciting new project with LangChain - come check it out!'),
#  Document(id='f7975f28-9cc6-4508-9bdb-c2c88f903230', metadata={'source': 'tweet'}, page_content='LangGraph is the best framework for building stateful, agentic applications!'),
#  Document(id='7a36738b-c853-4c1c-ab2f-5bd61f78645c', metadata={}, page_content='AI is future'),
#  Document(id='944f6afb-4e7e-49a4-b908-0c7f666bb98c', metadata={}, page_content='I like mexican food')]

# %%
vector_store_2 = FAISS.from_documents(
    documents, 
    embeddings, 
    distance_strategy="COSINE" # explicit cosine strategy
)

# %%
vector_store.as_retriever?
# Out:
# Signature: vector_store.as_retriever(**kwargs: 'Any') -> 'VectorStoreRetriever'
# Docstring:
# Return `VectorStoreRetriever` initialized from this `VectorStore`.
#
# Args:
#     **kwargs: Keyword arguments to pass to the search function.
#
#         Can include:
#
#         * `search_type`: Defines the type of search that the Retriever should
#             perform. Can be `'similarity'` (default), `'mmr'`, or
#             `'similarity_score_threshold'`.
#         * `search_kwargs`: Keyword arguments to pass to the search function.
#
#             Can include things like:
#
#             * `k`: Amount of documents to return (Default: `4`)
#             * `score_threshold`: Minimum relevance threshold
#                 for `similarity_score_threshold`
#             * `fetch_k`: Amount of documents to pass to MMR algorithm
#                 (Default: `20`)
#             * `lambda_mult`: Diversity of results returned by MMR;
#                 `1` for minimum diversity and 0 for maximum. (Default: `0.5`)
#             * `filter`: Filter by document metadata
#
# Returns:
#     Retriever class for `VectorStore`.
#
# Examples:
# ```python
# # Retrieve more documents with higher diversity
# # Useful if your dataset has many similar documents
# docsearch.as_retriever(
#     search_type="mmr", search_kwargs={"k": 6, "lambda_mult": 0.25}
# )
#
# # Fetch more documents for the MMR algorithm to consider
# # But only return the top 5
# docsearch.as_retriever(search_type="mmr", search_kwargs={"k": 5, "fetch_k": 50})
#
# # Only retrieve documents that have a relevance score
# # Above a certain threshold
# docsearch.as_retriever(
#     search_type="similarity_score_threshold",
#     search_kwargs={"score_threshold": 0.8},
# )
#
# # Only get the single most similar document from the dataset
# docsearch.as_retriever(search_kwargs={"k": 1})
#
# # Use a filter to only retrieve documents from a specific paper
# docsearch.as_retriever(
#     search_kwargs={"filter": {"paper_title": "GPT-4 Technical Report"}}
# )
# ```
# File:      c:\users\dell\appdata\roaming\python\python314\site-packages\langchain_core\vectorstores\base.py
# Type:      method

# %%
retriever = vector_store.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 2}
)

# %%
retrieved_documents = vector_store.similarity_search_with_score("Langchain provides abstractions to make working with LLMs easy",
    k=15)

# %%
r_doc = retrieved_documents[0]
len(r_doc)
# Out:
# 2

# %%
r_doc
# Out:
# (Document(id='cd1720f8-3b26-4d75-bb66-213d4e75fb95', metadata={'source': 'tweet'}, page_content='Building an exciting new project with LangChain - come check it out!'),
#  np.float32(0.57917786))

# %%
r_doc[1]
# Out:
# np.float32(0.57917786)

# %%
r_doc[0]
# Out:
# Document(id='cd1720f8-3b26-4d75-bb66-213d4e75fb95', metadata={'source': 'tweet'}, page_content='Building an exciting new project with LangChain - come check it out!')

# %%
# Above 60%

doc_lis = []
thresh = 0.5
for r_doc in retrieved_documents:
    score = r_doc[1]
    if score >= thresh:
        doc_lis.append(r_doc[0])

# %%
doc_lis
# Out:
# [Document(id='cd1720f8-3b26-4d75-bb66-213d4e75fb95', metadata={'source': 'tweet'}, page_content='Building an exciting new project with LangChain - come check it out!')]

# %%
vector_store.similarity_search_with_relevance_scores("Langchain provides abstractions to make working with LLMs easy",
    k=4)
# Out:
# [(Document(id='889739a6-feec-484b-8620-f9120ea997d0', metadata={'source': 'tweet'}, page_content='Building an exciting new project with LangChain - come check it out!'),
#   np.float32(0.5904594)),
#  (Document(id='541c128e-3102-4a3d-b725-805bf0c0cb40', metadata={'source': 'tweet'}, page_content='LangGraph is the best framework for building stateful, agentic applications!'),
#   np.float32(0.6529621)),
#  (Document(id='3af99412-84f4-448b-8fc4-0b2739f0b8d7', metadata={'source': 'tweet'}, page_content='I have a bad feeling I am going to get deleted :('),
#   np.float32(0.9794073)),
#  (Document(id='c973396f-1bc3-4a14-8f8e-a363a1767ee0', metadata={'source': 'news'}, page_content='Robbers broke into the city bank and stole $1 million in cash.'),
#   np.float32(0.99073684))]

# %%
retriever.invoke("Langchain provides abstractions to make working with LLMs easy")
# Out:
# [Document(id='889739a6-feec-484b-8620-f9120ea997d0', metadata={'source': 'tweet'}, page_content='Building an exciting new project with LangChain - come check it out!'),
#  Document(id='541c128e-3102-4a3d-b725-805bf0c0cb40', metadata={'source': 'tweet'}, page_content='LangGraph is the best framework for building stateful, agentic applications!')]

# %%
# Invoke the retriever
docs = retriever.invoke("LangChain projects")

for doc in docs:
    print(f"Content: {doc.page_content}")
    # Check if 'score' or 'relevance' exists in the metadata
    print(f"Metadata: {doc.metadata}")
# Out:
# Content: I have a bad feeling I am going to get deleted :(
# Metadata: {'source': 'tweet'}
# Content: The top 10 soccer players in the world right now.
# Metadata: {'source': 'website'}

# %% [markdown]
# # Chroma

# %%
# !pip install langchain-chroma chromadb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-chroma in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (1.1.0)
# Requirement already satisfied: chromadb in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (1.5.9)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from langchain-chroma) (1.4.6)
# Requirement already satisfied: numpy>=2.1.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from langchain-chroma) (2.3.5)
# Requirement already satisfied: build>=1.0.3 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pydantic>=2.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (2.13.4)
# Requirement already satisfied: pydantic-settings>=2.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (2.12.0)
# Requirement already satisfied: pybase64>=1.4.1 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (1.26.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: tokenizers>=0.13.2 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (36.0.2)
# Requirement already satisfied: tenacity>=8.2.3 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.0.16)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (24.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.25.0)
# Requirement already satisfied: anyio in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from httpx>=0.27.0->chromadb) (4.12.0)
# Requirement already satisfied: certifi in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from httpx>=0.27.0->chromadb) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from httpx>=0.27.0->chromadb) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from pydantic>=2.0->chromadb) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: pyproject_hooks in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=4.19.0->chromadb) (0.29.0)
# Requirement already satisfied: six>=1.9.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from kubernetes>=28.1.0->chromadb) (2.7.0)
# Requirement already satisfied: durationpy>=0.7 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from kubernetes>=28.1.0->chromadb) (3.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.22.0)
# Requirement already satisfied: flatbuffers in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.6)
# Requirement already satisfied: googleapis-common-protos~=1.57 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.42.1 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-proto==1.42.1 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.63b1)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from tokenizers>=0.13.2->chromadb) (0.36.0)
# Requirement already satisfied: filelock in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.12.0)
# Requirement already satisfied: click>=8.0.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: oauthlib>=3.0.0 in C:\Users\DELL\AppData\Roaming\Python\Python314\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_chroma import Chroma

# %%
vector_store = Chroma.from_documents(
    documents = documents,
    embedding=embeddings,
    collection_name = "l2_collection",
    persist_directory="./chroma_l2_db",
    collection_metadata = {"hnsw:space" : "l2"}
)

# %%
retriever = vector_store.as_retriever(search_kwargs = {"k":2})

# %%
retriever.invoke("Langchain provides abstractions to make working with LLMs easy")
# Out:
# [Document(id='dcd4e039-acda-4327-bc55-f9044af3c1ee', metadata={'source': 'tweet'}, page_content='Building an exciting new project with LangChain - come check it out!'),
#  Document(id='b7284a02-2d04-4350-9046-69c3286cc470', metadata={'source': 'tweet'}, page_content='LangGraph is the best framework for building stateful, agentic applications!')]
